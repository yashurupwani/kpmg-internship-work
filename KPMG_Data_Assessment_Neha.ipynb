# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
txn_data = pd.read_excel("C:/Users/admin/Desktop/KPMG Internship/KPMGData4analysis1.xlsx")
demographic = pd.read_excel("C:/Users/admin/Desktop/KPMG Internship/KPMGData4analysis1.xlsx",sheet_name = 1)
address = pd.read_excel("C:/Users/admin/Desktop/KPMG Internship/KPMGData4analysis1.xlsx",sheet_name = 2)
data = pd.read_excel("C:/Users/admin/Desktop/KPMG Internship/KPMGData4analysis1.xlsx",sheet_name = 3)

# %%
txn_data.head(6)
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
# 5               6          25         2339       2017-03-08           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
# 5     Approved  Giant Bicycles         Road        medium       medium
#
#    list_price  standard_cost  product_first_sold_date
# 0       71.49          53.62                  41245.0
# 1     2091.47         388.92                  41701.0
# 2     1793.43         248.82                  36361.0
# 3     1198.46         381.10                  36145.0
# 4     1765.30         709.48                  42226.0
# 5     1538.99         829.65                  39031.0

# %%
demographic.head(6)
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
# 5      Druci    Brandli  Female                                   39
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
# 5 1951-04-29     Assistant Media Planner         Entertainment
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# 1      Mass Customer                  N       No  ...    NSW  Australia
# 2  Affluent Customer                  N       No  ...    VIC  Australia
# 3  Affluent Customer                  N      Yes  ...    QLD  Australia
# 4  Affluent Customer                  N       No  ...    NSW  Australia
# 5     High Net Worth                  N      Yes  ...    QLD  Australia
#
#    property_valuation Unnamed: 16 Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# 0                   6        0.98       1.225      1.53125     1.301562
# 1                  11        0.88       0.880      1.10000     0.935000
# 2                   5        0.82       0.820      0.82000     0.820000
# 3                   1        0.80       1.000      1.00000     1.000000
# 4                   9        0.49       0.490      0.61250     0.612500
# 5                   7        0.54       0.675      0.67500     0.675000
#
#    Unnamed: 20  Rank     Value
# 0            1     1  1.718750
# 1            1     1  1.718750
# 2            1     1  1.718750
# 3            4     4  1.703125
# 4            4     4  1.703125
# 5            6     6  1.671875
#
# [6 rows x 23 columns]

# %%
address.head(6)
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
# 5            6            Curr  Duckhouse    Male
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
# 5                                   35 1966-09-16                     NaN
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# 2              Property      Mass Customer                  N
# 3                    IT      Mass Customer                  N
# 4                   NaN  Affluent Customer                  N
# 5                Retail     High Net Worth                  N
#
#                                              default owns_car  tenure
# 0                                                 "'      Yes    11.0
# 1                       <script>alert('hi')</script>      Yes    16.0
# 2                                2018-02-01 00:00:00      Yes    15.0
# 3  () { _; } >_[$($())] { touch /tmp/blns.shellsh...       No     7.0
# 4                                                NIL      Yes     8.0
# 5                                           ðµ ð ð ð      Yes    13.0

# %%
data.head(6)
# Out:
#    Unnamed: 0  customer_id              address  postcode            state  \
# 0         NaN            1   060 Morning Avenue      2016  New South Wales
# 1         NaN            2  6 Meadow Vale Court      2153  New South Wales
# 2         NaN            4   0 Holy Cross Court      4211              QLD
# 3         NaN            5  17979 Del Mar Point      2448  New South Wales
# 4         NaN            6     9 Oakridge Court      3216              VIC
# 5         NaN            7     4 Delaware Trail      2210  New South Wales
#
#      country  property_valuation
# 0  Australia                  10
# 1  Australia                  10
# 2  Australia                   9
# 3  Australia                   4
# 4  Australia                   9
# 5  Australia                   9

# %%
data.shape
# Out:
# (3999, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 7 columns):
# Unnamed: 0            0 non-null float64
# customer_id           3999 non-null int64
# address               3999 non-null object
# postcode              3999 non-null int64
# state                 3999 non-null object
# country               3999 non-null object
# property_valuation    3999 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 218.8+ KB

# %%
data.isnull().sum()
# Out:
# Unnamed: 0            3999
# customer_id              0
# address                  0
# postcode                 0
# state                    0
# country                  0
# property_valuation       0
# dtype: int64

# %%
#Mode Imputation
data['job_title'].fillna(data['job_title'].mode()[0],inplace=True)
data['job_industry_category'].fillna(data['job_industry_category'].mode()[0],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'job_title'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-96ba2e43c5fb> in <module>
#       1 #Mode Imputation
# ----> 2 data['job_title'].fillna(data['job_title'].mode()[0],inplace=True)
#       3 data['job_industry_category'].fillna(data['job_industry_category'].mode()[0],inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'job_title'

# %%
#Dropped the missing values from the Last Name and DOB variables
data = data.dropna(how='any',axis=0)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0            0
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
#Exported the csv format
data.to_csv("data.csv",index=False)

# %%
cat data.csv
# Out:
#   File "<ipython-input-19-aecaebae493b>", line 1
#     cat data.csv
#            ^
# SyntaxError: invalid syntax

# %%
#identified the record which is inconvenient
min(demographic['DOB'])
# Out:
# Timestamp('1938-06-08 00:00:00')

# %%
#Find the index
demographic['DOB'].loc[lambda x: x=='1843-12-21 00:00:00'].index
# Out:
# Int64Index([], dtype='int64')

# %%
max(demographic['DOB'])
# Out:
# Timestamp('2002-02-27 00:00:00')

# %%
demographic.head(34)
# Out:
#    first_name     last_name  gender  past_3_years_bike_related_purchases  \
# 0     Chickie       Brister    Male                                   86
# 1       Morly        Genery    Male                                   69
# 2     Ardelis     Forrester  Female                                   10
# 3      Lucine         Stutt  Female                                   64
# 4     Melinda        Hadlee  Female                                   34
# 5       Druci       Brandli  Female                                   39
# 6    Rutledge         Hallt    Male                                   23
# 7      Nancie          Vian  Female                                   74
# 8        Duff     Karlowicz    Male                                   50
# 9     Barthel        Docket    Male                                   72
# 10   Rockwell        Matson    Male                                   94
# 11    Wheeler       Winward    Male                                   48
# 12       Olag           NaN    Male                                   60
# 13      Melba      Spellacy  Female                                   38
# 14     Mandie        Feares  Female                                   32
# 15      Dukie         Swire    Male                                   88
# 16   Marcelia     Monkleigh  Female                                   61
# 17  Winnifred  Beswetherick  Female                                   83
# 18     Odilia         Quick  Female                                   65
# 19      Karly     Willavize  Female                                    2
# 20     Teddie      Burchill    Male                                   11
# 21     Gaston     Dallaghan    Male                                   44
# 22       Otis         Ottey    Male                                   26
# 23   Tabbatha       Averill  Female                                    5
# 24      Brena     Schnitter  Female                                   78
# 25     Rourke      Gillbard    Male                                   11
# 26      Dyane       Burwell  Female                                   19
# 27   Claudine      Barstowk  Female                                   71
# 28    Blinnie          Roze  Female                                   84
# 29      Rhona     De Freyne  Female                                   45
# 30    Sharron     Claibourn  Female                                   62
# 31      Brien        Heaton    Male                                   70
# 32    Sybilla       MacCart  Female                                   88
# 33      Mikel        McNess    Male                                   71
#
#           DOB                     job_title job_industry_category  \
# 0  1957-07-12               General Manager         Manufacturing
# 1  1970-03-22           Structural Engineer              Property
# 2  1974-08-28        Senior Cost Accountant    Financial Services
# 3  1979-01-28    Account Representative III         Manufacturing
# 4  1965-09-21             Financial Analyst    Financial Services
# 5  1951-04-29       Assistant Media Planner         Entertainment
# 6  1976-10-06          Compensation Analyst    Financial Services
# 7  1972-12-27  Human Resources Assistant II                Retail
# 8  1972-04-28            Speech Pathologist         Manufacturing
# 9  1985-08-02       Accounting Assistant IV                    IT
# 10 1995-01-01          Programmer Analyst I                Retail
# 11 1999-08-30      Environmental Specialist         Manufacturing
# 12 1990-05-13       Human Resources Manager    Telecommunications
# 13 1976-12-09                  VP Marketing                Health
# 14 1964-04-19           Clinical Specialist                Health
# 15 1954-03-31                           NaN         Manufacturing
# 16 1993-08-22           Associate Professor         Manufacturing
# 17 1976-06-08                       Actuary    Financial Services
# 18 1938-11-09               General Manager         Manufacturing
# 19 1954-08-12              Internal Auditor         Manufacturing
# 20 1968-12-21                  Programmer I         Manufacturing
# 21 1993-09-29             Financial Analyst    Financial Services
# 22 1998-02-05              Quality Engineer                   NaN
# 23 1977-12-17    Quality Control Specialist                   NaN
# 24 1982-10-11             Account Executive         Manufacturing
# 25 1945-08-03                           NaN              Property
# 26 1952-06-27                   Engineer II                Retail
# 27 1966-07-20                         Nurse              Property
# 28 1960-12-10                     Librarian         Entertainment
# 29 1960-11-22                           NaN                Health
# 30 1980-01-26                           NaN    Financial Services
# 31 1951-11-28           Clinical Specialist                Health
# 32 1987-01-15                     Paralegal    Financial Services
# 33 1981-09-22                         Nurse                   NaN
#
#        wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0       Mass Customer                  N      Yes  ...    QLD  Australia
# 1       Mass Customer                  N       No  ...    NSW  Australia
# 2   Affluent Customer                  N       No  ...    VIC  Australia
# 3   Affluent Customer                  N      Yes  ...    QLD  Australia
# 4   Affluent Customer                  N       No  ...    NSW  Australia
# 5      High Net Worth                  N      Yes  ...    QLD  Australia
# 6       Mass Customer                  N       No  ...    NSW  Australia
# 7       Mass Customer                  N      Yes  ...    QLD  Australia
# 8       Mass Customer                  N      Yes  ...    NSW  Australia
# 9       Mass Customer                  N      Yes  ...    QLD  Australia
# 10     High Net Worth                  N       No  ...    QLD  Australia
# 11      Mass Customer                  N       No  ...    VIC  Australia
# 12      Mass Customer                  N       No  ...    NSW  Australia
# 13      Mass Customer                  N       No  ...    NSW  Australia
# 14      Mass Customer                  N       No  ...    QLD  Australia
# 15  Affluent Customer                  N      Yes  ...    NSW  Australia
# 16      Mass Customer                  N      Yes  ...    QLD  Australia
# 17      Mass Customer                  N       No  ...    VIC  Australia
# 18  Affluent Customer                  N      Yes  ...    NSW  Australia
# 19     High Net Worth                  N       No  ...    NSW  Australia
# 20      Mass Customer                  N      Yes  ...    NSW  Australia
# 21      Mass Customer                  N      Yes  ...    NSW  Australia
# 22      Mass Customer                  N       No  ...    QLD  Australia
# 23  Affluent Customer                  N      Yes  ...    NSW  Australia
# 24      Mass Customer                  N       No  ...    QLD  Australia
# 25      Mass Customer                  N       No  ...    QLD  Australia
# 26      Mass Customer                  N      Yes  ...    NSW  Australia
# 27     High Net Worth                  N      Yes  ...    QLD  Australia
# 28     High Net Worth                  N       No  ...    QLD  Australia
# 29     High Net Worth                  N       No  ...    VIC  Australia
# 30     High Net Worth                  N      Yes  ...    NSW  Australia
# 31      Mass Customer                  N      Yes  ...    NSW  Australia
# 32      Mass Customer                  N      Yes  ...    NSW  Australia
# 33      Mass Customer                  N       No  ...    QLD  Australia
#
#     property_valuation Unnamed: 16 Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# 0                    6        0.98      1.2250     1.531250     1.301562
# 1                   11        0.88      0.8800     1.100000     0.935000
# 2                    5        0.82      0.8200     0.820000     0.820000
# 3                    1        0.80      1.0000     1.000000     1.000000
# 4                    9        0.49      0.4900     0.612500     0.612500
# 5                    7        0.54      0.6750     0.675000     0.675000
# 6                    7        0.93      0.9300     0.930000     0.790500
# 7                    5        0.77      0.9625     0.962500     0.818125
# 8                   10        1.10      1.3750     1.718750     1.460938
# 9                    5        1.10      1.3750     1.375000     1.168750
# 10                   6        0.51      0.5100     0.637500     0.637500
# 11                   8        0.62      0.6200     0.620000     0.527000
# 12                  11        0.89      0.8900     1.112500     0.945625
# 13                  10        0.51      0.5100     0.637500     0.541875
# 14                   8        0.74      0.7400     0.740000     0.629000
# 15                   8        0.71      0.8875     1.109375     1.109375
# 16                   6        1.01      1.2625     1.262500     1.073125
# 17                  10        0.45      0.4500     0.562500     0.478125
# 18                  11        0.84      1.0500     1.312500     1.312500
# 19                  10        0.48      0.4800     0.600000     0.600000
# 20                   9        0.94      1.1750     1.468750     1.248437
# 21                   7        0.87      1.0875     1.087500     0.924375
# 22                   4        0.61      0.6100     0.610000     0.518500
# 23                   8        0.86      1.0750     1.075000     1.075000
# 24                   5        0.60      0.6000     0.600000     0.510000
# 25                   4        1.06      1.0600     1.060000     0.901000
# 26                   2        0.46      0.5750     0.575000     0.488750
# 27                  11        0.71      0.8875     1.109375     1.109375
# 28                   7        0.97      0.9700     1.212500     1.212500
# 29                  10        0.75      0.7500     0.937500     0.937500
# 30                   8        0.49      0.6125     0.612500     0.612500
# 31                   2        0.73      0.9125     0.912500     0.775625
# 32                   7        0.50      0.6250     0.781250     0.664062
# 33                   9        0.51      0.5100     0.637500     0.541875
#
#     Unnamed: 20  Rank     Value
# 0             1     1  1.718750
# 1             1     1  1.718750
# 2             1     1  1.718750
# 3             4     4  1.703125
# 4             4     4  1.703125
# 5             6     6  1.671875
# 6             6     6  1.671875
# 7             8     8  1.656250
# 8             8     8  1.656250
# 9            10    10  1.640625
# 10           10    10  1.640625
# 11           12    12  1.625000
# 12           13    13  1.609375
# 13           14    14  1.593750
# 14           14    14  1.593750
# 15           16    16  1.562500
# 16           17    17  1.546875
# 17           17    17  1.546875
# 18           19    19  1.531250
# 19           19    19  1.531250
# 20           21    21  1.515625
# 21           21    21  1.515625
# 22           23    23  1.500000
# 23           23    23  1.500000
# 24           25    25  1.484375
# 25           26    26  1.468750
# 26           26    26  1.468750
# 27           26    26  1.468750
# 28           26    26  1.468750
# 29           30    30  1.460938
# 30           30    30  1.460938
# 31           32    32  1.453125
# 32           32    32  1.453125
# 33           32    32  1.453125
#
# [34 rows x 23 columns]

# %%
#Drop the 1843 record from the date field
demographic = demographic.drop(demographic.index[33])

# %%
#Now it's fine
min(demographic['DOB'])
# Out:
# Timestamp('1938-06-08 00:00:00')

# %%
demographic.shape
# Out:
# (999, 23)

# %%
#Check for the null values
demographic.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  164
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# Value                                    0
# dtype: int64

# %%
demographic['DOB'].dropna(axis=0,inplace=True)

# %%
demographic['tenure'].dtype
# Out:
# dtype('int64')

# %%
#Mean Imputation
demographic['tenure'].fillna(demographic['tenure'].mean(),inplace=True)

# %%
#Mode Imputation
demographic['job_industry_category'].fillna(demographic['job_industry_category'].mode()[0],inplace=True)

# %%
demographic['job_industry_category'].value_counts()
# Out:
# Financial Services    367
# Manufacturing         199
# Health                152
# Retail                 78
# Property               64
# IT                     51
# Entertainment          37
# Argiculture            26
# Telecommunications     25
# Name: job_industry_category, dtype: int64

# %%
#Dropped the irrelavent column
demographic = demographic.drop(['default'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-8d3a738f9da7> in <module>
#       1 #Dropped the irrelavent column
# ----> 2 demographic = demographic.drop(['default'],axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['default'] not found in axis"

# %%
#Dropped
demographic['job_title'].fillna('NA',inplace=True)
demographic['last_name'].fillna('NA',inplace=True)

# %%
demographic = demographic.dropna(how='any',axis=0)

# %%
demographic.isnull().sum()
# Out:
# first_name                             0
# last_name                              0
# gender                                 0
# past_3_years_bike_related_purchases    0
# DOB                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# deceased_indicator                     0
# owns_car                               0
# tenure                                 0
# address                                0
# postcode                               0
# state                                  0
# country                                0
# property_valuation                     0
# Unnamed: 16                            0
# Unnamed: 17                            0
# Unnamed: 18                            0
# Unnamed: 19                            0
# Unnamed: 20                            0
# Rank                                   0
# Value                                  0
# dtype: int64

# %%
demographic.shape
# Out:
# (982, 23)

# %%
demographic['gender'].value_counts()
# Out:
# Female    513
# Male      469
# Name: gender, dtype: int64

# %%
#Replaced the Category names
demographic = demographic.replace({'gender' : { 'M' : 'Male', 'F' : 'Female', 'Femal' : 'Female'}})

# %%
demographic['gender'].value_counts()
# Out:
# Female    513
# Male      469
# Name: gender, dtype: int64

# %%
demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 982 entries, 0 to 999
# Data columns (total 23 columns):
# first_name                             982 non-null object
# last_name                              982 non-null object
# gender                                 982 non-null object
# past_3_years_bike_related_purchases    982 non-null int64
# DOB                                    982 non-null datetime64[ns]
# job_title                              982 non-null object
# job_industry_category                  982 non-null object
# wealth_segment                         982 non-null object
# deceased_indicator                     982 non-null object
# owns_car                               982 non-null object
# tenure                                 982 non-null int64
# address                                982 non-null object
# postcode                               982 non-null int64
# state                                  982 non-null object
# country                                982 non-null object
# property_valuation                     982 non-null int64
# Unnamed: 16                            982 non-null float64
# Unnamed: 17                            982 non-null float64
# Unnamed: 18                            982 non-null float64
# Unnamed: 19                            982 non-null float64
# Unnamed: 20                            982 non-null int64
# Rank                                   982 non-null int64
# Value                                  982 non-null float64
# dtypes: datetime64[ns](1), float64(5), int64(6), object(11)
# memory usage: 184.1+ KB

# %%
#Exported as csv
demographic.to_csv("Customer Demographic")

# %%
txn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
# transaction_id             20000 non-null int64
# product_id                 20000 non-null int64
# customer_id                20000 non-null int64
# transaction_date           20000 non-null datetime64[ns]
# online_order               19640 non-null float64
# order_status               20000 non-null object
# brand                      19803 non-null object
# product_line               19803 non-null object
# product_class              19803 non-null object
# product_size               19803 non-null object
# list_price                 20000 non-null float64
# standard_cost              19803 non-null float64
# product_first_sold_date    19803 non-null float64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
txn_data.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
#replaced the category names and made the column binary
txn_data = txn_data.replace({'online_order' : { 0.0 : False, 1.0 : True}})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-07bce352918d> in <module>
#       1 #replaced the category names and made the column binary
# ----> 2 txn_data = txn_data.replace({'online_order' : { 0.0 : False, 1.0 : True}})
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4261             limit=limit,
#    4262             regex=regex,
# -> 4263             method=method,
#    4264         )
#    4265
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6669                     if set(keys) & set(values):
#    6670                         raise ValueError(
# -> 6671                             "Replacement not allowed with "
#    6672                             "overlapping keys and values"
#    6673                         )
#
# ValueError: Replacement not allowed with overlapping keys and values

# %%
#Mode Imputation
txn_data['online_order'].fillna(txn_data['online_order'].mode()[0],inplace=True)

# %%
txn_data['online_order'].value_counts()
# Out:
# 1.0    10189
# 0.0     9811
# Name: online_order, dtype: int64

# %%
#demographic['job_industry_category'] = demographic['job_industry_category'].fillna(demographic['job_industry_category'].mode())[0]
txn_data['brand'].fillna(txn_data['brand'].mode()[0],inplace=True)

# %%
txn_data['product_line'].fillna(txn_data['product_line'].mode()[0],inplace=True)

# %%
txn_data['product_size'].fillna(txn_data['product_size'].mode()[0],inplace=True)

# %%
txn_data['product_class'].fillna(txn_data['product_class'].mode()[0],inplace=True)

# %%
#Median Imputation
txn_data['standard_cost'].fillna(txn_data['standard_cost'].median(),inplace=True)

# %%
#dropped the remaining missing values
txn_data = txn_data.dropna(how='any',axis=0)

# %%
txn_data.isnull().sum()
# Out:
# transaction_id             0
# product_id                 0
# customer_id                0
# transaction_date           0
# online_order               0
# order_status               0
# brand                      0
# product_line               0
# product_class              0
# product_size               0
# list_price                 0
# standard_cost              0
# product_first_sold_date    0
# dtype: int64

# %%
#Exported as csv
txn_data.to_csv("Transaction")
